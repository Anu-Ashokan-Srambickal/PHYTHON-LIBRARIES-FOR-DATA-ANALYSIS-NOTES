# %% [markdown]
# # 📊 DATA VIZUALIZATION

# %% [markdown]
# ## 🍁 MATPLOTLIB

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - 🎨 Matplotlib is a powerful Python library used for creating static, animated, and interactive visualizations.

# %% [markdown]
# #### 🔍 Key Features

# %% [markdown]
# - Versatile Plotting: Line plots, bar charts, scatter plots, histograms, heatmaps, and more.
# - Customization: Control every aspect of your plot—colors, labels, legends, ticks, and styles.
# - Integration: Works seamlessly with NumPy, Pandas, and Jupyter Notebooks.
# - Export Options: Save figures in multiple formats like PNG, PDF, SVG, and EPS.

# %% [markdown]
# #### 🔮 GENERAL

# %% [markdown]
# - plt.xlabel & plt.ylabel is used to label x and y axix, size can be specified like(size=20)
# - plt.title is used for tile creation , size can be specified like(size=20)
# - Color can be customized by providing shorcuts(B-BLUE, G-GREEN ETC) and upper or lower case doesnt impact
# - plt.legend is used to create legend and it should be in [].

# %% [markdown]
# ____________

# %% [markdown]
# ### ☘️ LINE PLOT

# %% [markdown]
# - plt.plot : is used to create a line plot
# - x axis and y axis are mandatory for line plot
# - memory details of graph can be removed by either plt.show() or ;
# - Data point can be specified by marker using o,*,+  etc.
# - Colour also can be customized
# - linestyle'--', linewidth,

# %%
quaters = [1, 2,3,4]
revenue = [100, 200,90, 180]

# %%
plt.plot(quaters, revenue, marker='o', color='k', linestyle='--',linewidth=5)
plt.xlabel('Quaters', size=15)
plt.ylabel('Revenue', size=15)
plt.title('Revenue Generated Per Quater', size=20)
plt.show()

# %% [markdown]
# #### 🔰 MULTIPLE Y AXIS VALUES IN LINE PLOT - plt.plot

# %%
quaters = [1, 2,3,4]
revenue_2017 = [100, 200,90, 180]
revenue_2018 = [90, 250, 190, 250]

# %%
plt.plot(quaters, revenue_2017, marker='o', color='k', linestyle='--',linewidth=5)
plt.plot(quaters, revenue_2018, marker='*', color='y',linewidth=2)
plt.xlabel('Quaters', size=15)
plt.ylabel('Revenue', size=15)
plt.title('Revenue Generated Per Quater', size=20)
plt.legend(['Sales in 2017', 'Sales in 2018'])
plt.show()

# %% [markdown]
# _________

# %% [markdown]
# ### ☘️ BAR CHART - plt.bar

# %%
Categories = ['Categ_A', 'Categ_B', 'Categ_C', 'Categ_D']
Value_One = [15, 24, 30, 18]
Value_Two = [8,16,10,22]

# %%
fig = plt.figure(figsize=(20,8), dpi =250)
plt.bar(Categories, Value_One)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### 🔰 MULTIPLE BAR CHART

# %%
plt.bar(Categories, Value_One)
plt.bar(Categories, Value_Two)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### 🍀 HORIZONDAL BAR - plt.barh

# %%
plt.barh(Categories, Value_One)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ______________

# %% [markdown]
# ### ☘️ PIE CHART - plt.pie

# %% [markdown]
# - labels is used for labeling
# - autopct='%1.1f%%' is a code to add percentage in pie chart

# %%
labels = ['Category A', 'Category B', 'Category C', 'Category D']
sizes = [15, 24, 30, 18]

# %%
plt.pie(sizes, labels = labels, autopct='%1.1f%%');

# %%
plt.pie(sizes, labels = labels, autopct='%1.1f%%',colors=['skyblue', 'lightcoral', 'lightgreen'],
        wedgeprops={'edgecolor': 'white', 'linewidth': 1.5});

# %%
### ☘️ SCATTERPLOT - plt.scatter(attributes)

# %% [markdown]
# - Used to plot 2 continueous values.
# - plt.grid() to generate grid.
# - if x value is 5 then y is 7 likewise.

# %%
x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

# %%
plt.scatter(x, y);
plt.grid(True)

# %% [markdown]
# _____________

# %% [markdown]
# ### ☘️ HISTOGRAM - plt.hist(x)

# %% [markdown]
# - Used to plot Distribution of Dats

# %%
ages = [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]
ages
# Out:
# [18, 19, 21, 25, 26, 26, 30, 32, 38, 45, 55]

# %%
plt.hist(ages,  bins = 5, edgecolor='Black', color='Yellow');
