# %% [markdown]
# # 📊 DATA VIZUALIZATION

# %% [markdown]
# ## 🍁 SEABORN

# %% [markdown]
# LINK : https://seaborn.pydata.org/generated/seaborn.objects.Plot.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Surface Pro\Desktop\ENTRI APP\phython\Ivin notes\dm_office_sales.csv')
df.head(1)
# Out:
#    division level of education  training level  work experience  salary  \
# 0  printers       some college               2                6   91684
#
#     sales
# 0  372302

# %% [markdown]
# - hue parameter: Automatically creates legend of the parameter
# - x, y labels are created automatically.

# %% [markdown]
# ### 🍒 SCATTERPLOTS - sns.scatterplot(data, x, y)

# %% [markdown]
# - Continueous Numerical values should be given to x and y axis to create sctterplot

# %%
fig = plt.figure(figsize=(20,8), dpi =250)
sns.scatterplot(data=df, x='salary', y='sales', hue='division', size ='salary', style='division');

# %% [markdown]
# ________________

# %% [markdown]
# ### 🍒 BOXPLOT - sns.boxplot (data, x or y)  - sns.boxplot(data, x, y)

# %% [markdown]
# - Helps to find distribution and outliers.
# - BOX PLOT can be categorized to Q1, Q2 and Q3.(25%, 50%, 75%).

# %%
df['salary'].describe()
# Out:
# count      1000.000000
# mean      90264.207000
# std       17398.617174
# min       41660.000000
# 25%       77584.000000
# 50%       89946.000000
# 75%      101834.250000
# max      159148.000000
# Name: salary, dtype: float64

# %%
fig = plt.figure(figsize=(20,8), dpi =250)
sns.boxplot(data=df, x = 'salary')
# Out:
# <Axes: xlabel='salary'>

# %% [markdown]
# #### HORIZONDAL VERSION

# %%
fig = plt.figure(figsize=(20,8), dpi =250)
sns.boxplot(data=df, y= 'salary')
# Out:
# <Axes: ylabel='salary'>

# %%
sns.boxplot(data=df, x = 'salary', y = 'division');

# %%
sns.boxplot(data= df, x ='salary', y='division', hue='training level');

# %% [markdown]
# _______

# %% [markdown]
# ### 🍒 VIOLIN PLOT - sns.violinplot(data, x or y) - sns.violinplot(data, x , y)

# %% [markdown]
# - Shows the data distribution in q1, q2, q5.
# - same as box plt

# %%
sns.violinplot(data=df, x ='salary');

# %%
sns.violinplot(data=df, x='salary', y='division', color='red');

# %% [markdown]
# ______________

# %%
### 🍒 SWARMPLOT - sns.swarmplt(data, x)

# %% [markdown]
# - Similar to box plot and Violin plot
# - Shows Distrubution of Data Concentraction using Dots.

# %%
sns.swarmplot(data=df, x='salary');

# %% [markdown]
# _____________

# %% [markdown]
# ### 🍒 HISTOGRAMS - sns.histplot(data, x)

# %% [markdown]
# - Can be cuztomized using Bins.
# - Helps to find distribution or count.
# - Can be cuztomized using bins.

# %%
sns.histplot(data=df, x='salary');

# %%
sns.histplot(data=df, y='salary', bins=10, color='blue');

# %% [markdown]
# ___________

# %% [markdown]
# ### 🍒 DISPLOT - sns.displot(data, x)

# %% [markdown]
# - Combine many plot along with displot

# %%
sns.displot(data=df, x='salary')

# %%
sns.displot(data=df, x='salary', kde=True, rug='True');

# %% [markdown]
# ### 🍒 RUG PLOT - sns.rugplot(data, x)

# %% [markdown]
# - Used to find Distribution

# %%
sns.rugplot(data=df, x='salary');

# %% [markdown]
# ### 🍒 KDE PLOT - sns.kdeplot(data, x)

# %% [markdown]
# - Helps to find Distribution based on Density

# %%
sns.kdeplot(data=df, x= 'salary');

# %% [markdown]
# __________

# %% [markdown]
# ### 🍒 COUNTPLOT - sns.countplot(data, x)

# %% [markdown]
# - Shows count of objects in a column.

# %%
sns.countplot(data=df, x='division', color='green', legend=False);
plt.xticks(rotation=45, fontsize=10)
plt.show()

# %% [markdown]
# ________________

# %% [markdown]
# ### 🍒 PAIR PLOT - sns.pairplot(data)

# %% [markdown]
# - Summarizes numerical value of data set
# - Diagonally it is vizualized in Histogram (univariant analysis) and by Scatter plots (Bivariant analysis).

# %%
sns.pairplot(data = df );

# %%
numerical_columns = df[['salary', 'training level']]
numerical_columns
# Out:
#      salary  training level
# 0     91684               2
# 1    119679               2
# 2     82045               0
# 3     92949               2
# 4     71280               1
# ..      ...             ...
# 995   70083               1
# 996   68648               1
# 997  108354               2
# 998   79035               2
# 999  108444               0
#
# [1000 rows x 2 columns]

# %%
sns.pairplot(data = numerical_columns);

# %% [markdown]
# ____________

# %%
df_new = pd.read_csv(r'C:\Users\Surface Pro\Downloads\country_table.csv')
df_new.head(1)
# Out:
#   Countries  Birth rate  Mortality rate  Life expectancy  \
# 0    AFRICA      32.577           7.837           63.472
#
#    Infant mortality rate  Growth rate
# 0                 44.215         24.4

# %% [markdown]
# ### 🍒 HEATMAP - sns.heatmap(data=df)

# %% [markdown]
# - Used to analyse numerical datas of a dataset.

# %% [markdown]
# #### ✨ INDEXING COUNTRIES

# %% [markdown]
# - By indexing the country, there will be no error caused by string data.

# %%
df_new = df_new.set_index('Countries')
df_new
# Out:
#                                  Birth rate  Mortality rate  Life expectancy  \
# Countries
# AFRICA                               32.577           7.837           63.472
# ASIA                                 15.796           7.030           73.787
# EUROPE                               10.118          11.163           78.740
# LATIN AMERICA AND THE CARIBBEAN      15.886           6.444           75.649
# NORTHERN AMERICA                     11.780           8.833           79.269
# OCEANIA                              16.235           6.788           78.880
# WORLD                                17.963           7.601           72.766
#
#                                  Infant mortality rate  Growth rate
# Countries
# AFRICA                                          44.215        24.40
# ASIA                                            23.185         8.44
# EUROPE                                           3.750         0.38
# ...

# %%
sns.heatmap(data=df_new);

# %%
sns.heatmap(data=df_new, linewidth=1);

# %%
sns.heatmap(data=df_new, linewidth=1, annot=True);

# %% [markdown]
# #### ✨ REMOVING A COLUMN

# %%
sns.heatmap(data=df_new.drop('Life expectancy', axis =1), linewidth=1, annot=True);  # removed for uniformity of colors

# %% [markdown]
# #### ✨ IF A DATA SET HAS MORE STRING , THIS METHOD CAN BE USED

# %%
numbers_only = df.select_dtypes(include='number')
numbers_only
# Out:
#      training level  work experience  salary   sales
# 0                 2                6   91684  372302
# 1                 2               10  119679  495660
# 2                 0                9   82045  320453
# 3                 2                5   92949  377148
# 4                 1                5   71280  312802
# ..              ...              ...     ...     ...
# 995               1                1   70083  177953
# 996               1                0   68648  103703
# 997               2                8  108354  450011
# 998               2                3   79035  330354
# 999               0                9  108444  364436
#
# [1000 rows x 4 columns]

# %%
sns.heatmap(data=numbers_only);   # large dataset

# %% [markdown]
# _____________

# %% [markdown]
# #### 🍒 PIVOT TABLES

# %% [markdown]
# - Creating a pivot table in Python is super straightforward when using the pandas library.
# - It’s a powerful way to summarize and analyze data

# %%
data = {
    'Region': ['East', 'West', 'East', 'North', 'West', 'South'],
    'Product': ['A', 'B', 'A', 'C', 'B', 'C'],
    'Sales': [100, 200, 150, 300, 250, 400]
}

df = pd.DataFrame(data)

# %%
pivot = pd.pivot_table(df, 
                       index='Region',     # rows
                       columns='Product',  # columns
                       values='Sales',     # values to aggregate
                       aggfunc='sum',      # aggregation function
                       fill_value=0)       # fill missing values

# %% [markdown]
# #### 🧠 Bonus Tips
#
# - You can use other aggregation functions like 'mean', 'count', 'max', 'min', or even custom functions.
# - For multi-level pivot tables, you can pass lists to index or columns.

# %% [markdown]
# _______________
