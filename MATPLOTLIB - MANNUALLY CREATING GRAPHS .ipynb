# %% [markdown]
# ## 🍁 MANNUALLY CREATING A GRAPH

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 🍒 CODE FOR CREATING FIGURE OBJECT

# %%
fig = plt.figure()

# %% [markdown]
# #### 🍂 CODE FOR CREATING AN AXIS OBJECT - RECTANGULAR BOX WITH 4 CORNES

# %% [markdown]
# - First 2 digits [0, 0] implies to Co-ordinates
# - While Second 2 digits applies for width and height of the rectangular box

# %%
ax = fig.add_axes([0, 0, 1, 1])

# %% [markdown]
# #### 🍂 CODE FOR CREATING A PLOT

# %%
# axialobject.plot
ax.plot

# %% [markdown]
# #### 🍂 FOR CREATING A FIGURE OBJECT WE HAVE TO COMBINE ALL THESE CODES IN A CELL

# %% [markdown]
# ##### 🍡 LINE PLOT

# %%
x = [100, 200, 300, 400]
y = [1250, 780, 810, 1875]

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x,y);

# %% [markdown]
# ___________

# %% [markdown]
# ## 🍒 CREATING GRAPH WITHIN A GRAPH

# %% [markdown]
# ### 🍂 FOR THIS MULTIPLE AXIS HAS TO BE PROVIDED BASED ON THE REQUIREMENT

# %%
- [0.5, 0.5] in ax1 refers to width and height. [ranges from 0-1]
- [0,0] in ax1 refers to crate a axial figure from bottom length of existing plot.

# %%
ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0, 0, 0.5, 0.5])

# %% [markdown]
# ####  ☘️ PRACTICING

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0, 0, 0.5, 0.5])
ax.plot(x,y);

# %% [markdown]
# #### ☘️ ADJUSTING CO-ORDINATES OF SECOND AXIS

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.3, 0.3, 0.5, 0.5])
ax.plot(x,y);

# %% [markdown]
# #### ADJUSTING AXIAL PLOT TOWARDS LEFT

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.1, 0.3, 0.5, 0.5])
ax.plot(x,y);

# %% [markdown]
# #### ☘️ ADJUSTING THE SECOND AXIAL PLOT TOWARDS THE TOP

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.1, 0.45, 0.5, 0.5])
ax.plot(x,y);

# %%
#### ADJUSTING HEIGHT AND WITH

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.1, 0.45, 0.3, 0.3])
ax.plot(x,y);

# %% [markdown]
# #### 🍉 PLOTING THE SECOND GRAPH

# %%
x = [100, 200, 300, 400]
y = [1250, 780, 810, 1875]

# %%
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.1, 0.45, 0.3, 0.3])

ax.plot(x,y)
ax1.plot(x,y);

# %% [markdown]
# ______________

# %% [markdown]
# ### 🍒 CREATING A DIFFERENT SUB PLOT

# %%
x = [100, 200, 300, 400]
y = [1250, 780, 810, 1875]

# %%
a = np.arange(0,10)
b = (a**5) + 25

# %%
fig = plt.figure(figsize=(20,8), dpi =250)


ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.4, 0.5, 0.3, 0.3])

ax.plot(x,y, color='blue')
ax1.plot(a,b, color='red');

# %% [markdown]
# #### ☘️ LABELING X AND Y AXIS  - ax.set_xlabel & ylabel

# %%
fig = plt.figure(figsize=(20,8), dpi =250)


ax = fig.add_axes([0, 0, 1, 1])
ax1 = fig.add_axes([0.4, 0.5, 0.3, 0.3])

ax.plot(x,y, color='blue')
# labeling
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')

ax1.plot(a,b, color='red');
ax1.set_xlabel('A axis')
ax1.set_ylabel('B axis')
# Out:
# Text(0, 0.5, 'B axis')

# %% [markdown]
# __________

# %% [markdown]
# ### ⭐️ ADVANTAGES

# %% [markdown]
# - Can cuztomize figure size
# - plt.figure(figsize=(20,8)) which meand 20 width and 8 height.
# - Figsize should be provided in a Tuple.
# - DPI : Dots per Inches, controls resolution of image.
# - As the 'dpi' Value increases resolution increases and it depends on RAM.

# %% [markdown]
# ____________
